# %%
from IPython.core.display import HTML, Image
css = open('style/style-table.css').read() + open('style/style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
kaixiang_wang={'name':'Kaixiang Wang',
               'area_of_research':'control engineering',
               'institution':'University of Melbourne',
               'coffee':'cappuccino',
               'pet_name':'',
               'date_of_workshop':'8/6/2016-9/6/2016',
              'email':'kaixiangw@student.unimelb.edu.au'}
print(kaixiang_wang['area_of_research'])
# add an additional key
kaixiang_wang['comment']='No comment. '*16
assert(len(kaixiang_wang['comment'])<=200)
# Out:
# control engineering

# %%
'2016-06-09'.split('-')
# Out:
# ['2016', '06', '09']

# %%
comment='No comment. '*20
def shorten(comment):
    '''
    takes in a string, shorten it to 200-long string and output it
    '''
    l=len(comment)//2
    comment=comment[l-100:l+100]
    return comment
def 
s_comment=shorten(comment)
print(len(s_comment))
s_comment
# Out:
# 200
# 'nt. No comment. No comment. No comment. No comment. No comment. No comment. No comment. No comment. No comment. No comment. No comment. No comment. No comment. No comment. No comment. No comment. No c'

# %%
range(5)
# Out:
# range(0, 5)

# %%
# Kaixiang Wang
kaixiang_wang={'name':'Kaixiang Wang',
               'area_of_research':'control engineering',
               'institution':'University of Melbourne',
               'coffee':'cappuccino',
               'pet_name':'',
               'date_of_workshop':'8/6/2016-9/6/2016',
              'email':'kaixiangw@student.unimelb.edu.au'}
# add an additional key
kaixiang_wang['comment']='No comment. '*16

# Stephan
stephan_oehler = {'name':'Stephan Oehler','area_of_research':'FlowControl','institution':'The University of Melbourne','coffee':'I do not do drugs!','pet_name':'pupsi','date_of_worksop':'08-09 June 2016'}
comment = ('I really like this workshop! Can there be a Java one as well please? Please do not tell the people to close their terminal at the start of the first session, this would help for the Markdown task  ....')
if len(comment) <= 200:
    stephan_oehler['comments'] = comment
else:
    stephan_oehler['comments'] = 'I an sorry Alistair, but my comment was too long to be included'
    
# Changfu

# Chenyang

# %%
import pandas as pd
data=pd.read_csv('https://bit.ly/uforeports')

# %%
type(data)
type(data['City'])
data.loc[0:5,'State':'Time']
# Out:
#   State             Time
# 0    NY   6/1/1930 22:00
# 1    NJ  6/30/1930 20:00
# 2    CO  2/15/1931 14:00
# 3    KS   6/1/1931 13:00
# 4    NY  4/18/1933 19:00
# 5    ND  9/15/1934 15:30

# %%
data_city=pd.read_csv('https://bit.ly/uforeports',index_col='City')
data_city
# Out:
#        Colors Reported Shape Reported State              Time
# City
# Ithaca             NaN       TRIANGLE    NY    6/1/1930 22:00
# Ithaca             NaN          CIGAR    NY    6/1/1979 19:00
# Ithaca             NaN          OTHER    MI    6/1/1987 17:00
# Ithaca             NaN          OTHER    NY    1/10/1993 0:30
# Ithaca       RED GREEN          LIGHT    NY  10/15/1994 18:00
# Ithaca             NaN            NaN    NY   2/16/1996 21:45
# Ithaca             NaN          FLASH    MI    6/3/2000 22:35
# Ithaca             NaN       TEARDROP    NY   7/30/2000 20:20

# %%
data_multiple=pd.read_csv('https://bit.ly/uforeports',index_col=['City','State'])
#data_multiple.loc['Ithaca','NY']
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
# City               18216 non-null object
# Colors Reported    2882 non-null object
# Shape Reported     15597 non-null object
# State              18241 non-null object
# Time               18241 non-null object
# dtypes: object(5)
# memory usage: 712.6+ KB

# %%
drinks_data=pd.read_csv('https://bit.ly/drinksbycountry')
ds1=drinks_data.loc[0:10,'beer_servings':'total_litres_of_pure_alcohol']
ds2=drinks_data.iloc[0:11,1:-1]

drinks_data
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
# the following command allows inline plot
# %matplotlib inline

import this



drinks_data_country=pd.read_csv('https://bit.ly/drinksbycountry',index_col='country')
drinks_data_country.loc[:,'total_litres_of_pure_alcohol'].plot()

# %%
data=pd.read_csv('data/inflammation.csv',header=None) # header=none tells the raw data has no header
# %matplotlib inline
type(data.iloc[0:1,:5])
data.iloc[0,:5].plot()
data.T.shape
data.iloc[0:5,:].T.plot()

# %%
import matplotlib.pyplot as plt

plt.imshow(data)
type(data.mean())
type(data.values)
data.iloc[0,:][data.iloc[0,:]>5]
# Out:
# 7      7
# 8      8
# 12    10
# 14     7
# 16     7
# 17     7
# 18    12
# 19    18
# 20     6
# 21    13
# 22    11
# 23    11
# 24     7
# 25     7
# 27     6
# 28     8
# 29     8
# 33     7
# Name: 0, dtype: int64

# %%
col=drinks_data_country.columns[1]
type(drinks_data_country[col])
type(col)
drinks_data_country.spirit_servings # both are the same
drinks_data_country[col]
# Out:
# country
# Afghanistan               0
# Albania                 132
# Algeria                   0
# Andorra                 138
# Angola                   57
# Antigua & Barbuda       128
# Argentina                25
# Armenia                 179
# Australia                72
# Austria                  75
# Azerbaijan               46
# Bahamas                 176
# Bahrain                  63
# Bangladesh                0
# Barbados                173
# Belarus                 373
# Belgium                  84
# Belize                  114
# Benin                     4
# Bhutan                    0
# Bolivia                  41
# Bosnia-Herzegovina      173
# Botswana                 35
# Brazil                  145
# Brunei                    2
# Bulgaria                252
# Burkina Faso              7
# Burundi                   0
# Cote d'Ivoire             1
# Cabo Verde               56
#                        ...
# Suriname                178
# Swaziland                 2
# ...

# %%
import seaborn as sns
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
titanic=sns.load_dataset('titanic')
#titanic.groupby('sex').age.plot(kind='hist',bins=16)
type(titanic.groupby('sex'))

titanic.groupby('sex').age.plot(kind='hist',bins=16,alpha=.5)
# Out:
# sex
# female    Axes(0.125,0.125;0.775x0.775)
# male      Axes(0.125,0.125;0.775x0.775)
# Name: age, dtype: object

# %%
titanic[titanic.sex=='male'].age.plot(kind='hist',range=(0,100),bins=20,alpha=.5,label='male')
titanic[titanic.sex=='female'].age.plot(kind='hist',range=(0,100),bins=20,alpha=1,label='female')
